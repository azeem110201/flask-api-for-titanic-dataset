# %%
url = 'http://127.0.0.1:5000/'

# %%
import requests,json

# %%
# sample data
data = {'Pclass': 3
      , 'Age': 2
      , 'SibSp': 1
      , 'Fare': 50}
data = json.dumps(data)

# %%
send_request =requests.post(url,data)

# %%
print(send_request)
# Out:
# <Response [200]>

# %%
print(send_request.json())
# Out:
# {'results': {'results': 1}}

# %%
heroku_url = 'https://flask-api-for-titanic.herokuapp.com/' # change to your app name
# sample data
data = {  'Pclass': 1
             , 'Age': 60
             , 'SibSp': 1
             , 'Fare': 14}
data = json.dumps(data)

# %%
send_request = requests.post(heroku_url, data)
print(send_request)
# Out:
# <Response [200]>

# %%
print(send_request.json())
# Out:
# {'results': {'results': 0}}
